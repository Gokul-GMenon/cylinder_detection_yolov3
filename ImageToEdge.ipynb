# %%
root_dir = '/content/drive/MyDrive/yolov3'

# %%
# import zipfile
# with zipfile.ZipFile(os.path.join(root_dir, 'dataset.zip'), 'r') as zip_ref:
#     zip_ref.extractall(root_dir)

# %%
import matplotlib.pyplot as plt
import cv2
import os

root_dir = os.path.join(root_dir, 'dataset')

folder = ['train', 'test']

for i in range(2):
    
    dir = os.path.join(root_dir, folder[i])
    print(dir)
    for img in os.listdir(dir):
    
        if not img.endswith(".jpg"):
            continue

        image = cv2.imread(os.path.join(dir, img))


        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        blur = cv2.GaussianBlur(gray,(5,5),2)
        th3 = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV,11,2)
        ret, res = cv2.threshold(th3, 70, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

        image = cv2.cvtColor(res, cv2.COLOR_GRAY2RGB)
        
        
        cv2.imwrite(os.path.join(dir, img), image)
# Out:
# hi
# /content/drive/MyDrive/yolov3/dataset/test
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_13_11_33_25_418_jpg.rf.10bd150fdaaaba5bc4981ab5c27623fc.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_13_12_19_37_1582_jpg.rf.0862e71e812ddf85d0254a54f3ffae25.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_13_13_58_50_3975_jpg.rf.3190bc80a105f8c0e176150e05a2bf1f.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_13_15_03_01_5587_jpg.rf.c2499f087284f9dc55364532198948a5.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_13_15_44_05_6647_jpg.rf.623fc3d254449a460652fbde568de36b.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_14_12_26_10_498_jpg.rf.fb4792e7214c5bab1ea0784875108151.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_14_12_49_37_1090_jpg.rf.a3050842d353404137b0ff41f7ca7601.jpg
# /content/drive/MyDrive/yolov3/dataset/test/2021_02_14_14_44_05_3613_jpg.rf.d38c5bd11d38c1a98599fe626edb5ae0.jpg
# ...
